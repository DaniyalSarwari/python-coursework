# %% [markdown]
# <a href="https://colab.research.google.com/github/DaniyalSarwari/python-coursework/blob/main/fundamentals/06_functions/00_averages.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Problem Statement
#
# Write a function that takes two numbers and finds the average between the two.

# %% [markdown]
# ## Solution

# %%
def average(number_1: int, number_2: int)-> int:
  return (number_1 + number_2) / 2

def main():
  num_1: int = int(input("Enter Number 1: "))
  num_2: int = int(input("Enter Number 2: "))
  print(f"Average is {average(num_1, num_2)}")

if __name__ == '__main__':
    main()
# Out:
# Enter Number 1: 3
# Enter Number 2: 4
# Average is 3.5
