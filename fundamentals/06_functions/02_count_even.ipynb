# %% [markdown]
# <a href="https://colab.research.google.com/github/DaniyalSarwari/python-coursework/blob/main/fundamentals/06_functions/02_count_even.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Problem Statement
#
# Fill out the function `count_even(lst)` which
#
# first populates a list by prompting the user for integers until they press enter (please use the prompt `"Enter an integer or press enter to stop: "`),
#
# and then prints the number of even numbers in the list.

# %% [markdown]
# ## Solution

# %%
def count_even(lst: list)-> int:
  count: int = 0
  for item in lst:
    if item % 2 == 0:
      count += 1
  return count


def main():
  number_list: list = []
  while True:
    user_input: str = input("Enter an integer or press enter to stop: ")
    if user_input == "":
      break
    else:
      number_list.append(int(user_input))

  count: int  = count_even(number_list)
  print("Total Even Numbers: ", count)
if __name__ == '__main__':
    main()
# Out:
# Enter an integer or press enter to stop: 2
# Enter an integer or press enter to stop: 3
# Enter an integer or press enter to stop: 4
# Enter an integer or press enter to stop: 5
# Enter an integer or press enter to stop: 7
# Enter an integer or press enter to stop:
# Total Even Numbers:  2
