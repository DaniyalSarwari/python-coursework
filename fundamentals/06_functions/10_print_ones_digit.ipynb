# %% [markdown]
# <a href="https://colab.research.google.com/github/DaniyalSarwari/python-coursework/blob/main/fundamentals/06_functions/10_print_ones_digit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Problem Statement
#
# Write a function called `print_ones_digit` , which takes as a parameter an integer num and prints its ones digit. The modulo (remainder) operator, %, should be helpful to you here. Call your function from main()!
#
# Here's a sample run:
# ```
# Enter a number: 42
# The ones digit is 2
# ```

# %% [markdown]
# ## Solution

# %%
def print_ones_digit(num: int)-> None:
  print("The ones digit is ", str(num)[-1])

def main():
  numbr: int = int(input("Enter a number: "))
  print_ones_digit(numbr)

if __name__ == '__main__':
    main()
# Out:
# Enter a number: 42
# The ones digit is  2
