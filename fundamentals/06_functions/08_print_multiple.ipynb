# %% [markdown]
# <a href="https://colab.research.google.com/github/DaniyalSarwari/python-coursework/blob/main/fundamentals/06_functions/08_print_multiple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Problem Statement
#
# Fill out `print_multiple(message, repeats)`, which takes as parameters a string message to print, and an integer repeats number of times to print message. We've written the main() function for you, which prompts the user for a message and a number of repeats.
#
# Here's a sample run of the program:
# ```
# Please type a message: Hello!
# Enter a number of times to repeat your message: 6
# Hello! Hello! Hello! Hello! Hello! Hello!
# ```

# %% [markdown]
# ## Solution

# %%
def print_multiple(message: str, repeats: int)-> None:
  for count in range(repeats):
    print(message, end=' ')

def main():
  msg: str = input("Please type a message: ")
  count: int = int(input("Enter a number of times to repeat your message: "))
  print_multiple(msg, count)

if __name__ == '__main__':
    main()
# Out:
# Please type a message: Hello!!
# Enter a number of times to repeat your message: 6
# Hello!! Hello!! Hello!! Hello!! Hello!! Hello!!
