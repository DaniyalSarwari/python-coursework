# %% [markdown]
# <a href="https://colab.research.google.com/github/DaniyalSarwari/python-coursework/blob/main/fundamentals/01_expressions/02_e%3Dmc2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Problem Statement
#
# Write a program that continually reads in mass from the user and then outputs the equivalent energy using Einstein's mass-energy equivalence formula (E stands for energy, m stands for mass, and C is the speed of light:
#
# `E = m * c**2`
#
# > Almost 100 years ago, Albert Einstein famously discovered that mass and energy are interchangeable and are related by the above equation. You should ask the user for mass (m) in kilograms and use a constant value for the speed of light -- C = 299792458 m/s.
#
# Here's a sample run of the program (user input is in bold italics):
# ```
# Enter kilos of mass: 100
#
# e = m * C^2...
#
# m = 100.0 kg
#
# C = 299792458 m/s
#
# 8.987551787368176e+18 joules of energy!
# ```

# %% [markdown]
# ## Solution

# %%
LIGHT_SPEED: int = 299792458

def main():
  mass: float = float(input("Enter kilos of mass: "))
  energy = mass * LIGHT_SPEED ** 2
  print("e = m * C^2")
  print(f"m = {mass:.1f} kg")
  print(f"C = {LIGHT_SPEED} m/s")
  print(f"{energy} joules of energy!")

if __name__ == '__main__':
    main()
# Out:
# Enter kilos of mass: 100
# e = m * C^2
# m = 100.0 kg
# C = 299792458 m/s
# 8.987551787368176e+18 joules of energy!
