# %% [markdown]
# <a href="https://colab.research.google.com/github/DaniyalSarwari/python-coursework/blob/main/fundamentals/01_expressions/03_feet_to_inches.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Problem Statement
#
# Converts feet to inches. Feet is an American unit of measurement. There are 12 inches per foot. Foot is the singular, and feet is the plural.

# %% [markdown]
# ## Solution

# %%
FOOT: int = 12

def main():
  feet: float = float(input("Enter Feet: "))
  print(f"{feet} Feet = {feet * FOOT} inches")

if __name__ == '__main__':
    main()
# Out:
# Enter Feet: 10
# 10.0 Feet = 120.0 inches
