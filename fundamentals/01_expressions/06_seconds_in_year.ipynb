# %% [markdown]
# <a href="https://colab.research.google.com/github/DaniyalSarwari/python-coursework/blob/main/fundamentals/01_expressions/06_seconds_in_year.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Problem Statement
#
# Use Python to calculate the number of seconds in a year, and tell the user what the result is in a nice print statement that looks like this (of course the value 5 should be the calculated number instead):
#
# `There are 5 seconds in a year!`
#
# You should use constants for this exercise -- there are 365 days in a year, 24 hours in a day, 60 minutes in an hour, and 60 seconds per minute.

# %% [markdown]
# ## Solution

# %%
MINUTES: int = 60
HOUR: int = 60
DAY: int = 24
YEAR: int = 365

def main():
  seconds: int = YEAR * DAY * HOUR * MINUTES
  print(f"There are {seconds} seconds in a year!")

if __name__ == '__main__':
    main()
# Out:
# There are 31536000 seconds in a year!
