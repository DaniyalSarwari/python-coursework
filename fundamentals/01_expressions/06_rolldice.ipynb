# %% [markdown]
# <a href="https://colab.research.google.com/github/DaniyalSarwari/python-coursework/blob/main/fundamentals/01_expressions/06_rolldice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Problem Statement
#
# Simulate rolling two dice, and prints results of each roll as well as the total.

# %% [markdown]
# ## Solution

# %%
import random

def main():
  ddice_one: int
  dice_two: int

  print("=== Rolling dice ===")
  dice_one = random.randint(1,6)
  dice_two = random.randint(1,6)

  print("Dice One: ", dice_one)
  print("Dice Two: ", dice_two)
  print("Total: ",dice_one + dice_two)


if __name__ == '__main__':
    main()
# Out:
# === Rolling dice ===
# Dice One:  5
# Dice Two:  4
# Total:  9
