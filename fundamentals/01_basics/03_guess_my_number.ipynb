# %% [markdown]
# <a href="https://colab.research.google.com/github/DaniyalSarwari/python-coursework/blob/main/fundamentals/01_basics/03_guess_my_number.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Problem Statement
#
# Guess My Number
# ```
# I am thinking of a number between 0 and 99...
# Enter a guess: 50
# Your guess is too high
#
# Enter a new number: 25
# Your guess is too low
#
# Enter a new number: 40
# Your guess is too low
#
# Enter a new number: 45
# Your guess is too low
#
# Enter a new number: 48
# Congrats! The number was: 48
# ```

# %% [markdown]
# ## Solution

# %%
import random

def main():
  system_number: int = random.randint(0, 99)
  print("I am thinking of a number between 0 and 99...")

  guess: int = int(input("Enter a guess: "))
  while guess != system_number:

    if guess < system_number:
      print("Your guess is too low")
    else:
      print("Your guess is too high")

    guess = int(input("\nEnter a new number: "))

  if guess == system_number:
    print("Congrats! The number was: ", guess)

if __name__ == '__main__':
    main()
# Out:
# I am thinking of a number between 0 and 99...
# Enter a guess: 50
# Your guess is too high
#
# Enter a new number: 25
# Your guess is too low
#
# Enter a new number: 35
# Your guess is too high
#
# Enter a new number: 30
# Your guess is too high
#
# Enter a new number: 26
# Your guess is too low
#
# Enter a new number: 27
# Congrats! The number was:  27
