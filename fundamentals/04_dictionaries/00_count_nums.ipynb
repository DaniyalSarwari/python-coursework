# %% [markdown]
# <a href="https://colab.research.google.com/github/DaniyalSarwari/python-coursework/blob/main/fundamentals/04_dictionaries/00_count_nums.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Problem Statement
#
# This program counts the number of times each number appears in a list. It uses a dictionary to keep track of the information.
#
# An example run of the program looks like this :
# ```
# Enter a number: 3
# Enter a number: 4
# Enter a number: 3
# Enter a number: 6
# Enter a number: 4
# Enter a number: 3
# Enter a number: 12
# Enter a number:
# 3 appears 3 times.
# 4 appears 2 times.
# 6 appears 1 times.
# 12 appears 1 times.
# ```

# %% [markdown]
# ## Solution

# %%
def main():
  track: dict[int,int] = {}
  input_number: int = None
  while True:
    input_number: str = input("Enter a number: ")
    if input_number == '':
      break
    else:
      input_number = int(input_number)

    if input_number not in track:
      track[input_number] = 1
    elif input_number in track:
      track[input_number] += 1
  # print(track)
  for key, val in track.items():
    print(f"{key} appears {val} times.")


if __name__ == '__main__':
    main()
# Out:
# Enter a number: 3
# Enter a number: 4
# Enter a number: 3
# Enter a number: 6
# Enter a number: 4
# Enter a number: 3
# Enter a number: 12
# Enter a number:
# 3 appears 3 times.
# 4 appears 2 times.
# 6 appears 1 times.
# 12 appears 1 times.
