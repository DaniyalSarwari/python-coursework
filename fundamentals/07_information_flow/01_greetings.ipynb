# %% [markdown]
# <a href="https://colab.research.google.com/github/DaniyalSarwari/python-coursework/blob/main/fundamentals/07_information_flow/01_greetings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Problem Statement
#
# We've written a helper function for you called `greet(name)` which takes as input a string name and prints a greeting. Write some code in main() to get the user's name and then greet them, being sure to call the `greet(name)` helper function.
#
# Here's a sample run of the program:
# ```
# What's your name? Sophia
#
# Greetings Sophia!
# ```

# %% [markdown]
# ## Solution

# %%
def greet(name: str) -> None:
  print("Greetings ", name)

def main():
  person_name: str = input("What's your name? ")
  greet(person_name)

if __name__ == '__main__':
    main()
# Out:
# What's your name? Daniyal
# Greetings  Daniyal
