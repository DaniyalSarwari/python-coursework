# %% [markdown]
# <a href="https://colab.research.google.com/github/DaniyalSarwari/python-coursework/blob/main/fundamentals/07_information_flow/02_in_range.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Problem Statement
#
# Implement the following function which takes in 3 integers as parameters:
#
# ```
# def in_range(n, low, high)
# """ Returns True if n is between low and high, inclusive.
# high is guaranteed to be greater than low. """
# ```

# %% [markdown]
# ## Solution

# %%
def in_range(n: int, low: int, high: int) -> bool:
  if low <= n <= high:
    return True
  else:
    return False
