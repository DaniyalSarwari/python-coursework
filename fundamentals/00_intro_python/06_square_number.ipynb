# %% [markdown]
# <a href="https://colab.research.google.com/github/DaniyalSarwari/python-coursework/blob/main/fundamentals/00_intro_python/06_square_number.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Problem Statement
#
# Ask the user for a number and print its square (the product of the number times itself).
#
# Here's a sample run of the program (user input is in bold italics):
#
# `Type a number to see its square: 4`
#
# `4.0 squared is 16.0`

# %% [markdown]
# ## Solution

# %%
def main():
  input_number: float = float(input("Type a number to see its square: "))
  print(f"{input_number:.1f} squared is {input_number**2}")


if __name__ == '__main__':
    main()
# Out:
# Type a number to see its square: 4
# 4.0 squared is 16.0
