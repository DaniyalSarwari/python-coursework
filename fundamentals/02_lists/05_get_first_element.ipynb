# %% [markdown]
# <a href="https://colab.research.google.com/github/DaniyalSarwari/python-coursework/blob/main/fundamentals/02_lists/05_get_first_element.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Problem Statement
#
# Fill out the function **get_first_element(lst)** which takes in a list lst as a parameter and prints the first element in the list. The list is guaranteed to be non-empty. We've written some code for you which prompts the user to input the list one element at a time.

# %% [markdown]
# ## Solution

# %%
def get_first_element(lst: list)-> None:
  print(lst[0])

def main():
  mylist: list = []
  while True:
    item: str = input("Please enter list item or press enter to exit: ")
    if item != "":
      mylist.append(item)
    else:
      break

  get_first_element(mylist)

# This provided line is required at the end of
# Python file to call the main() function.
if __name__ == '__main__':
    main()
# Out:
# Please enter list item or press enter to exit: Hi
# Please enter list item or press enter to exit: How
# Please enter list item or press enter to exit: are
# Please enter list item or press enter to exit: You
# Please enter list item or press enter to exit:
# Hi
