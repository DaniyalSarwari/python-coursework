# %% [markdown]
# <a href="https://colab.research.google.com/github/DaniyalSarwari/python-coursework/blob/main/fundamentals/02_lists/08_shorten.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Problem Statement
#
# Fill out the function **shorten(lst)** which removes elements from the end of lst, which is a list, and prints each item it removes until lst is MAX_LENGTH items long. If lst is already shorter than MAX_LENGTH you should leave it unchanged. We've written a main() function for you which gets a list and passes it into your function once you run the program. For the autograder to pass you will need MAX_LENGTH to be 3, but feel free to change it around to test your program.

# %% [markdown]
# ## Solution

# %%
MAX_LENGTH: int = 5

def shorten(lst: list) -> None:
  while len(lst) > MAX_LENGTH:
    print(lst.pop())

def main():
  mylist: list = []
  print("Initially list: ", mylist)
  while True:
    item: str = input("Enter a value: ")
    if item != "":
      mylist.append(item)
    else:
      break
  print("After adding elements: ", mylist)
  shorten(mylist)
  print("List is now: ", mylist)

# This provided line is required at the end of
# Python file to call the main() function.
if __name__ == '__main__':
    main()
# Out:
# Initially list:  []
# Enter a value: 1
# Enter a value: 2
# Enter a value: 3
# Enter a value: 4
# Enter a value: 5
# Enter a value: 6
# Enter a value: 7
# Enter a value:
# After adding elements:  ['1', '2', '3', '4', '5', '6', '7']
# 7
# 6
# List is now:  ['1', '2', '3', '4', '5']
