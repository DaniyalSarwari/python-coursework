# %% [markdown]
# <a href="https://colab.research.google.com/github/DaniyalSarwari/python-coursework/blob/main/fundamentals/02_lists/06_get_last_element.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Problem Statement
#
# Fill out the function **get_last_element(lst)** which takes in a list lst as a parameter and prints the last element in the list. The list is guaranteed to be non-empty, but there are no guarantees on its length.

# %% [markdown]
# ## Solution

# %%
def get_first_element(lst: list)-> None:
  size: int = len(lst)
  print(lst[size-1])

def main():
  mylist: list = []
  while True:
    item: str = input("Please enter list item or press enter to exit: ")
    if item != "":
      mylist.append(item)
    else:
      break

  get_first_element(mylist)

# This provided line is required at the end of
# Python file to call the main() function.
if __name__ == '__main__':
    main()
# Out:
# Please enter list item or press enter to exit: Daniyal
# Please enter list item or press enter to exit: Mahmood
# Please enter list item or press enter to exit: Sarwari
# Please enter list item or press enter to exit:
# Sarwari
